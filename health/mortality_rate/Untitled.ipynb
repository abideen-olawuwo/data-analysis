# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv('mortality_and_global_health_estimates_indicators_nga.csv')
df.shape
# Out:
# (4185, 39)

# %%
df.head()
# Out:
#         GHO (CODE)                                      GHO (DISPLAY)  \
# 0  #indicator+code                                    #indicator+name
# 1    GBD_DALYRTAGE               Age-standardized DALYs (per 100,000)
# 2    WHOSIS_000004  Adult mortality rate (probability of dying bet...
# 3    WHOSIS_000004  Adult mortality rate (probability of dying bet...
# 4    WHOSIS_000004  Adult mortality rate (probability of dying bet...
#
#                                            GHO (URL) PUBLISHSTATE (CODE)  \
# 0                                     #indicator+url        #status+code
# 1  https://www.who.int/data/gho/indicator-metadat...           PUBLISHED
# 2  https://www.who.int/data/gho/indicator-metadat...           PUBLISHED
# 3  https://www.who.int/data/gho/indicator-metadat...           PUBLISHED
# 4  https://www.who.int/data/gho/indicator-metadat...           PUBLISHED
#
#   PUBLISHSTATE (DISPLAY)  PUBLISHSTATE (URL)  YEAR (CODE) YEAR (DISPLAY)  \
# ...

# %%
# let's check unique values
columns=df.columns
for col in columns:
    print(col,':\n',df[col].unique())
    print(df[col].value_counts())
    print('\n',20*'**','\n')
# Out:
# GHO (CODE) :
#  ['#indicator+code' 'GBD_DALYRTAGE' 'WHOSIS_000004' 'MORT_300'
#  'WHOSIS_000015' 'LIFE_0000000029' 'LIFE_0000000032' 'LIFE_0000000030'
#  'WHS2_126' 'LIFE_0000000031' 'LIFE_0000000033' 'LIFE_0000000034'
#  'LIFE_0000000035' 'WHS2_131' 'CHILDMORT_MORTALITY_10TO14'
#  'MDG_0000000007' 'MDG_0000000001' 'WHOSIS_000003' 'WHOSIS_000014'
#  'CHILDMORT5TO14' 'WHOSIS_000016' 'CM_01' 'CM_02' 'CM_03' 'CM_04'
#  'CHILDMORT_DEATHS_10TO14' 'MDG_0000000026' 'MORT_MATERNALNUM']
# MORT_300                      756
# LIFE_0000000034               285
# LIFE_0000000029               285
# LIFE_0000000032               285
# LIFE_0000000030               285
# LIFE_0000000035               285
# LIFE_0000000031               285
# LIFE_0000000033               285
# MDG_0000000001                174
# MDG_0000000007                174
# CM_02                         171
# CM_01                         159
# CHILDMORT_DEATHS_10TO14        96
# CM_04                          96
# ...
